# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.describe()

# %%
df.head(5)

# %%
df.tail(5)

# %%
df.isnull().sum()

# %%
df.shape

# %%
df.size

# %%
df.describe

# %%
df.notnull()

# %%
df.info()

# %%
df.Age.mean()

# %%
df.Age.mode()

# %%
df.Age.max()

# %%
df.Age.min()

# %%
print("Minimum values:\n", df.min(numeric_only=True))

# %%
print("Maximum values:\n", df.max(numeric_only=True))

# %%
df.median(numeric_only=True)

# %%
df.std(numeric_only=True)

# %%
grouped = df.groupby(['Age', 'Annual Income (k$)']).agg({'Spending Score (1-100)': ['mean', 'median', 'max', 'min', 'std', 'count']})
print(grouped)

# %%
df['Gender'] = df['Gender'].map({'Male': '0', 'Female': '1'})
df.median()

# %%
df_u = df.rename(columns={'Age': 'C_Age', 'Annual Income (k$)': 'Annual Income '})
df.mode()
